# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# Golbal variable

# %%
api_key = ""

root_url = "https://api.arkhamintelligence.com"
headers = {
    "API-Key": api_key
}
funds = {
    'Grayscale': "grayscale",
    'BlackRock': "blackrock",
    'Fidelity': "fidelity",
    'Bitwise': "bitwise",
    'VanEck': "vaneck",
    'MicroStrategy': "microstrategy",
    'ARK Invest': "ark-invest",
    
}
cexes ={
    'Binance': "binance",
    'Coinbase': "coinbase",
    'OKX': "okx",
    'Bitfinex': "bitfinex",
    'Bybit': "bybit",
    'Kraken': "kraken",
}   
tokens = {
    'BTC': "bitcoin",
    'ETH': "ethereum",
    'STX': "blockstack",
    'JUP': "jupiter-exchange-solana",
    'SOL': "solana",
    'TIA': "celestia",
    "INJ": "injective-protocol",
    "SEI": "sei-network",
    "WHALES": "whales-market",
    "DYM": "dymension",
    "ARKM" : "arkham",
    'LINK': "chainlink",
    "PYTH": "pyth-network",
    
}
fromArr = [funds['Grayscale'], funds['Fidelity'], funds['BlackRock'], funds['Bitwise'], funds['VanEck']]
baseArr = fromArr
cexAndFundsArr = list(cexes.values()) + list(funds.values());
etherscanRoot = f'https://etherscan.io/tx/'
bitcoinRoot = f'https://blockstream.info/tx/'
arkhamEntityRoot = f'https://platform.arkhamintelligence.com/explorer/entity/'
arkhamAddressRoot = f'https://platform.arkhamintelligence.com/explorer/address/'
arkhamTxRoot = f'https://platform.arkhamintelligence.com/explorer/tx/'
chatId = ''
root_url_telegram = 'https://api.telegram.org/bot:'
send_path = f"{root_url_telegram}/sendMessage?chat_id={chatId}&text="
# Out:
# ['binance', 'coinbase', 'okx', 'bitfinex', 'bybit', 'kraken', 'grayscale', 'blackrock', 'fidelity', 'bitwise', 'vaneck', 'microstrategy', 'ark-invest']

# %%
class arkham_transfer: # path = "/transfer"
        
        def __init__(self, base=[], chains=[], flow="all", From=[], to=[], tokens=[], timeGte=0, 
                    timeLte=0, timeLast="1m", valueGte=0, valueLte=0, usdGte=0, usdLte=0, sortKey="value", sortDir="desc", limit=20, offset=100):
            self.params = {
                "base" : base, # ftx, binance, grayscale...
                "chains" : chains, # ethereum, bitcoin...
                "flow" : flow, # in, out, default = all
                "from" : From, # type:binance,despoit:all
                "to" : to, # just like from
                "tokens" : tokens, # tokens address
                "timeGte" : timeGte, #篩選出區塊_時間戳大於或等於特定時間的交易。
                "timeLte" : timeLte, #篩選出區塊_時間戳<於或等於特定時間的交易。
                "timeLast" : timeLast, # last 1d, 1h, 1m, 1s
                "valueGte" : valueGte, # 篩選出超過特定代幣單位價值的轉帳資訊  
                "valueLte" : valueLte, # 篩選出<過特定代幣單位價值的轉帳資訊
                "usdGte" : usdGte, # just like valueGte, but in usd base format
                "usdLte" : usdLte,
                "sortKey" : sortKey, # "time", "value", "usd"
                "sortDir" : sortDir, # "asc", "desc"
                "limit" : limit, # 返回的轉帳結果數量，預設至20筆。最多10,000筆。
                "offset" : offset,   
            }
            self.url = "/transfers"
        
        def set_params(self, params):
            self.params = params
        def get_params(self):
            return self.params
        def request_tx(self):
            data = requests.get(url=f'{root_url}{self.url}', headers=headers, params=self.params)
            if data.status_code == 200:
                return data.json()
            else:
                print("Error! "+str(data.status_code))
                return None

# %%
def convertTimeStampToUTCTime(time):
    utc_time = datetime.utcfromtimestamp(float(time))
    utc_time_plus_8 = utc_time + timedelta(hours=16)
    date_str = utc_time_plus_8.strftime('%Y-%m-%d %H:%M:%S')
    return date_str
def convertBlockTimeToUTCTime(blockTimestamp):
    datetimeobj = datetime.strptime(blockTimestamp, '%Y-%m-%dT%H:%M:%SZ')
    timestamp = datetimeobj.timestamp()
    return convertTimeStampToUTCTime(timestamp)
def get_cur_timestamp():
        # Get the current time in UTC+8
    current_time = datetime.now()
    # Calculate the start time for the last 60 minutes
    start_time = current_time

    # Convert the start time to a timestamp in milliseconds
    active_timeStamp = int(start_time.timestamp())*1000

    utc_time = datetime.utcfromtimestamp(active_timeStamp/1000) + timedelta(hours=8)
    date_str = utc_time.strftime('%Y-%m-%d %H:%M:%S')
    print(date_str)
    return int(active_timeStamp/1000)
def get_last_3_min_timestamp(timeStamp):
    timeStamp = float(timeStamp)
    utc_time = datetime.utcfromtimestamp(timeStamp) - timedelta(minutes=3)
    res = utc_time
    utc_time = utc_time + timedelta(hours=8)
    date_str = utc_time.strftime('%Y-%m-%d %H:%M:%S')
    print(date_str)
    return int(res.timestamp())

# %%
obj = arkham_transfer()

params = {
    "base": cexAndFundsArr, 
    "flow" : "all",
    "to": cexAndFundsArr,
    "timeLast": "5m",
    "tokens": list(tokens.values()),
    "sortKey": "time",
    "valueGte" : 1, # 篩選出超過特定代幣單位價值的轉帳資訊  
    "sortDir": "desc",
    "limit": 10000,
}
obj.set_params(params)

# %%
obj.get_params()
# Out:
# {'base': ['binance',
#   'coinbase',
#   'okx',
#   'bitfinex',
#   'bybit',
#   'kraken',
#   'grayscale',
#   'blackrock',
#   'fidelity',
#   'bitwise',
#   'vaneck',
#   'microstrategy',
#   'ark-invest'],
#  'flow': 'all',
#  'to': ['binance',
#   'coinbase',
#   'okx',
#   'bitfinex',
#   'bybit',
#   'kraken',
#   'grayscale',
#   'blackrock',
#   'fidelity',
#   'bitwise',
#   'vaneck',
#   'microstrategy',
#   'ark-invest'],
#  'timeLast': '3h',
#  'tokens': ['bitcoin',
#   'ethereum',
#   'blockstack',
#   'jupiter-exchange-solana',
#   'solana',
#   'celestia',
#   'injective-protocol',
#   'sei-network',
#   'whales-market',
#   'dymension',
#   'arkham',
#   'chainlink',
#   'pyth-network'],
#  'sortKey': 'time',
#  'valueGte': 1,
#  'sortDir': 'desc',
#  'limit': 10000}

# %%
# toAddress would probably be a list of address labeled as a entity name
# just loop through the toAddress list and find the first labeled address and get the entity name then done, 
# seem as the list of fromAddress 
# EntityA: len(toAddress), EntityB: len(FromAddress)
# Transfer value = 'fromValue'
# we want:
# 1. ['fromAddress']['arkhamEntity']['name']
# or ['fromAddresses'][n]['arkhamEntity']['name']

# %% [markdown]
# # examples

# %% [markdown]
# ## Examples of message

# %% [markdown]
# Network: Ethereum (1)
# Transaction Hash: 0x..... (should be a hyperlink) (1)
# State: Successful (1)
# Block: #3123213 (1)
# Time: 3 小时 前( 1月25, 2024 15:54:35 UTC+8) (1)
# From: EntityA (1)
# To: EntityB (1)
# Value: 1 ETH ($2330 USD) (1)
#
# 網路：以太坊 (1)
# 交易哈希：0x.....（應該是超連結）(1)
# 狀態：成功 (1)
# 區塊：#3123213 (1)
# 時間: 3小時前( 2024年1月25日 15:54:35 UTC+8) (1)
# 來自：實體A (1)
# 至：實體B (1)
# 價值：1 ETH（2330 美元）(1)

# %%
def findTheMostValueAddress(addressList):
    if addressList == None: return None
    if len(addressList) == 0 or 1: return None
    bestValue = None
    resEntity, resAddress, resLabel, resChain  = None, None, None, None
    for address in addressList:
        each = address['address']
        curValue = address['value']
        if bestValue == None: 
            bestValue = curValue
            if 'arkhamLabel' in each: resLabel = each['arkhamLabel']['name']
            if 'chain' in each:
                resChain = each['chain']
            if 'arkhamEntity' in each:
                resEntity = each['arkhamEntity']['name']
            if 'address' in each:
                resAddress = each['address']
        if curValue > bestValue:
            if 'arkhamLabel' in each: resLabel = each['arkhamLabel']['name']
            if 'chain' in each:
                resChain = each['chain']
            if 'arkhamEntity' in each:
                resEntity = each['arkhamEntity']['name']
            if 'address' in each:
                resAddress = each['address']
            bestValue = curValue
    
    return resChain, resEntity, resLabel, resAddress, bestValue

# %%
def process(tx):
    msg = None
    try:
        # divide all the userful data
        chain,txhash,block,time,From,to,value = None,None,None,None,None,None,None
        fromArkhamLabeledName, USDValue, toArkhamLabeledName = None, None, None
        fromAddress, toAddress, toEntity, fromEntity, toValue = None, None, None, None, None
        # fromAddresses or fromAddress
        # toAddresses or toAddress
        # to find the token name, the network, the from's entity, and the to's entity
        
        # from entity
        if 'fromAddress' in tx:
            From = tx['fromAddress']
            if 'arkhamLabel' in From: fromArkhamLabeledName = From['arkhamLabel']['name']
            chain = From['chain']
            if 'arkhamEntity' in From: fromEntity = From['arkhamEntity']['name']
            if 'address' in From: fromAddress = From['address']
        else: # fromAddresses
            addressList = tx['fromAddresses']
            for address in addressList:
                each = address['address']
                if 'arkhamLabel' in each: fromArkhamLabeledName = each['arkhamLabel']['name']
                if 'chain' in each:
                    chain = each['chain']
                if 'arkhamEntity' in each:
                    fromEntity = each['arkhamEntity']['name']
                if 'address' in each: 
                    fromAddress = each['address']
                if chain != None and fromEntity != None: break
                
        # to entity
        if 'toAddress' in tx:
            to = tx['toAddress']
            if 'arkhamLabel' in to: toArkhamLabeledName = to['arkhamLabel']['name']
            chain = to['chain']
            if 'arkhamEntity' in to: toEntity = to['arkhamEntity']['name']
            if 'address' in to: toAddress = to['address']
        else: # toAddresses
            addressList = tx['toAddresses']
            chain, toEntity, toArkhamLabeledName, toAddress, toValue = findTheMostValueAddress(addressList=addressList)

        if 'transactionHash' in tx:
            txhash = tx['transactionHash'] 
        elif 'txid' in tx:
            txhash = tx['txid']
        if 'blockTimestamp' in tx:
            time =str(convertBlockTimeToUTCTime(tx['blockTimestamp'])) + " UTC+8"
        if 'blockNumber' in tx:
            block = str(tx['blockNumber'])
        elif 'blockHeight' in tx:
            block = str(tx['blockHeight'])
        if toValue == None: toValue = 0
        if 'fromValue' in tx:
            # alpha value
            if 'toValue' in tx:
                toValue = float(tx['toValue'])
            value = tx['fromValue']
            if float(toValue) > float(value):
                value = float(toValue)
        else:
            if 'toValue' in tx:
                toValue = float(tx['toValue'])
            value = tx["unitValue"]
            if float(toValue) > float(value):
                value = float(toValue)
        USDValue = f"(${tx['historicalUSD']} USD)"
        # convert them to readable text
        if chain == 'ethereum':
            arkhamHash = arkhamTxRoot+txhash
            # txhash = etherscanRoot+txhash
            valueFormat = 'ETH'
        elif chain == 'bitcoin':
            arkhamHash = arkhamTxRoot+txhash
            # txhash = bitcoinRoot+txhash
            valueFormat = 'BTC'
        else:
            if chain == 'None': chain = 'unknown, will be updated soon'
            arkhamHash = arkhamTxRoot+txhash
            valueFormat = tx['tokenSymbol']
            print("error: "+txhash)
        if fromArkhamLabeledName == None: fromArkhamLabeledName = '(unlabeled)'
        if toArkhamLabeledName == None: toArkhamLabeledName = '(unlabeled)'
        # toLink = f'<a href="{arkhamEntityRoot}{to.lower()}">{toArkhamLabeledName}</a>'
        # fromLink = f'<a href="{arkhamEntityRoot}{From.lower()}">{fromArkhamLabeledName}</a>'
        # txLink = f'<a href="{arkhamTxRoot}{txhash}">查看交易</a>'
        # msg = f"""網路: {chain}\n交易哈希: {txhash}\n狀態: 成功\n區塊: {block}\n時間: {time}\nFrom: {fromEntity}: {fromArkhamLabeledName} ({fromAddress})\nTo: {toEntity}: {toArkhamLabeledName} ({toAddress})\n價值: {value} {valueFormat} {USDValue} \nCheck it on Arkham! => {arkhamHash}"""
        # send it to the telegram chat
        text1 = f"網路: {chain}"
        text2 = f"交易哈希: {txhash[:5]}..."
        text3 = "狀態: 成功"
        text4 = f"區塊: {block}"
        text5 = f"時間: {time}"
        text6 = f"From: {fromEntity}: {fromArkhamLabeledName} ({fromAddress[:5]})"
        text7 = f"To: {toEntity}: {toArkhamLabeledName} ({toAddress[:5]})"
        text8 = f"價值: {value} {valueFormat} {USDValue}" 
        text9 = f"Check it on Arkham! => {arkhamHash}" 

        msg = "\n".join([text9, text1, text2, text3, text4, text5, text6, text7, text8])
        print(msg)
        return msg
    except Exception as e:
        print("發生異常：", str(e))
        print("txHash: "+txhash)

# %%
data = obj.request_tx()
tx_list = data['transfers']

for tx in tx_list:
    
    msg = process(tx)
    if msg != None: requests.get(send_path+msg)
# Out:
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xfbcfe54a1af2109c04cedcf8f62f9cbf8e28cf41f3f15e1b7d191099034978f4
# 網路: ethereum
# 交易哈希: 0xfbc...
# 狀態: 成功
# 區塊: 19298614
# 時間: 2024-02-25 00:24:11 UTC+8
# From: None: Coinbase Deposit (0xD64)
# To: Coinbase: (unlabeled) (0xA9D)
# 價值: 2.255179104988962 ETH ($6678.735471215862 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x2cf02273e5215d1c1db2fd27d2b0094b98dc09eb0e594adbdeabe8b9d957305c
# 網路: ethereum
# 交易哈希: 0x2cf...
# 狀態: 成功
# 區塊: 19298614
# 時間: 2024-02-25 00:24:11 UTC+8
# From: None: Coinbase Deposit (0xb50)
# To: Coinbase: (unlabeled) (0x95A)
# 價值: 1.000154331969776 ETH ($2961.967055671812 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x7792a7d4ab19f8067a303ada2ebcf6c5e4415b8af0b106469b53b85b10d53ba6
# 網路: ethereum
# 交易哈希: 0x779...
# 狀態: 成功
# 區塊: 19298610
# 時間: 2024-02-25 00:23:23 UTC+8
# From: None: Kraken Deposit (0xE75)
# To: Kraken: (unlabeled) (0x267)
# 價值: 1 ETH ($2961.51 USD)
# error: 0x2bc1bf039259e1e8f92e3d6cea388686eed2fa7f9aab20bc8aa56209acd06918
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x2bc1bf039259e1e8f92e3d6cea388686eed2fa7f9aab20bc8aa56209acd06918
# 網路: base
# 交易哈希: 0x2bc...
# 狀態: 成功
# 區塊: 11001215
# 時間: 2024-02-25 00:22:57 UTC+8
# From: None: (unlabeled) (0x4B1)
# To: Bybit: (unlabeled) (0xBae)
# 價值: 1.49612 ETH ($4430.7743412 USD)
# error: 0x3830aa9d4fed317022ee67edbdcd31c19a8d95571006e95c37aff0b3a5f77cae
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x3830aa9d4fed317022ee67edbdcd31c19a8d95571006e95c37aff0b3a5f77cae
# 網路: arbitrum_one
# 交易哈希: 0x383...
# 狀態: 成功
# 區塊: 184046931
# 時間: 2024-02-25 00:22:45 UTC+8
# From: None: OKX Deposit (0x5Ee)
# To: OKX: (unlabeled) (0x093)
# 價值: 1.04995582 ETH ($3109.4546604882003 USD)
# error: 0x55347b6fdf7e0f1e3bb99a4a942f144a372d67590fe0bf5816d61c88269e90d5
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x55347b6fdf7e0f1e3bb99a4a942f144a372d67590fe0bf5816d61c88269e90d5
# 網路: arbitrum_one
# 交易哈希: 0x553...
# 狀態: 成功
# 區塊: 184046891
# 時間: 2024-02-25 00:22:35 UTC+8
# From: None: OKX Deposit (0x646)
# To: OKX: (unlabeled) (0x093)
# 價值: 1.07209899 ETH ($3175.0318798749004 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xd304ca8a503b3077b0546b6cb39f18287c94766cbda25fbbbe3614b89ebfaff0
# 網路: ethereum
# 交易哈希: 0xd30...
# 狀態: 成功
# 區塊: 19298605
# 時間: 2024-02-25 00:22:23 UTC+8
# From: None: Bybit Deposit (0x70c)
# To: Bybit: (unlabeled) (0xf89)
# 價值: 1.5563608491030974 ETH ($4609.178218227314 USD)
# error: 0xd3f81b55ce8a3fac306c707ae2fb5be295d69be46afcd3c81457d9b57c29671b
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xd3f81b55ce8a3fac306c707ae2fb5be295d69be46afcd3c81457d9b57c29671b
# 網路: arbitrum_one
# 交易哈希: 0xd3f...
# 狀態: 成功
# 區塊: 184046831
# 時間: 2024-02-25 00:22:20 UTC+8
# From: None: OKX Deposit (0xc8e)
# To: OKX: (unlabeled) (0x093)
# 價值: 2.26693168 ETH ($6713.5408396368 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x5315a721af358c0baada689ec2d777c13692308dbde706686d536559607b51c6
# 網路: ethereum
# 交易哈希: 0x531...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0xFCc)
# To: Coinbase: (unlabeled) (0xA9D)
# 價值: 2.406852 ETH ($7127.91626652 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x9be93c8a7b2cf5aa1e34947593b70f541c0d9af0bfeb6d7112cd86610832e264
# 網路: ethereum
# 交易哈希: 0x9be...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0x743)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 29.729271939999997 ETH ($88043.5361430294 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xba4f61de361e2a223da7ca43ff81e880fb56fade6486c6852fa5deb5df42a68a
# 網路: ethereum
# 交易哈希: 0xba4...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0x285)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.74072784 ETH ($5155.1829054384 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x281170d1185876d7ad9ed887ef8489e52c767c08221d407040b465922249db99
# 網路: ethereum
# 交易哈希: 0x281...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0x500)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.5992371 ETH ($4736.156664021 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x995928d21107ca6b2501372b1ac4102add23cee0ac81e02aff440f93b1a6d7ed
# 網路: ethereum
# 交易哈希: 0x995...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: Coinbase Deposit (0xa42)
# To: Coinbase: (unlabeled) (0xA9D)
# 價值: 3.499009888730519 ETH ($10362.352775574322 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x97a0e77f56a2c4c3223fc57a274506f92bb630dc55ed59a843cfd045f4f8c653
# 網路: ethereum
# 交易哈希: 0x97a...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0x9F5)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.82949165 ETH ($5418.057816391501 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xb76d40b4123b27ad48262011694c65a1e93a42ef46c345772c7448a81b6c475b
# 網路: ethereum
# 交易哈希: 0xb76...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0x908)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 2.30073724 ETH ($6813.6563436324 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x833355cb802653e5331a5edf19347e57c1030ead37ea1a62a30f838bee6b4ca1
# 網路: ethereum
# 交易哈希: 0x833...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0x0ee)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 2.96524166 ETH ($8781.5928285066 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x64cd63949d9ca99244f433586f4f712b9d354a9c147b96c0ba854050a2b2fab5
# 網路: ethereum
# 交易哈希: 0x64c...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0x25C)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 2.799139 ETH ($8289.67813989 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xc51cb71f71a68abe585c14700864031bbfc490b712adcc705ac0af1f0a5703fc
# 網路: ethereum
# 交易哈希: 0xc51...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0x1d9)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.00808574 ETH ($2985.4559998674004 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x766551586c1bf7bc7ffceef2f0ecd31d278b918b9149403d0539dd36fbbcc20b
# 網路: ethereum
# 交易哈希: 0x766...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: Coinbase Deposit (0xB54)
# To: Coinbase: (unlabeled) (0xb73)
# 價值: 1.6005037738776835 ETH ($4739.907931376499 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x3628175e9f61098c6968987fe54ebe5a131d484d071a914da28f766757d102da
# 網路: ethereum
# 交易哈希: 0x362...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0xd35)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.94644032 ETH ($5764.4024720832 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x76a25c20d60516205007231dea5e28ab5c1557b22b82a63fed7c123ef700d473
# 網路: ethereum
# 交易哈希: 0x76a...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0xF50)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 2.97516517 ETH ($8810.9814026067 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x9d9d85ae2ea95a2e8af68ef69d22f1c9506254924d9cf64dad01f714fe359602
# 網路: ethereum
# 交易哈希: 0x9d9...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0x844)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 4.89654668 ETH ($14501.1719582868 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xa1227191c2736cdec6d96882e3d091d09db97cea34d81bd8de0f6e439bb4bcd1
# 網路: ethereum
# 交易哈希: 0xa12...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0x642)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.68104598 ETH ($4978.4344802298 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xf1fd5e3143d68998b293068066154c570929e5be8f6ce71a201cee0bf8e4fa54
# 網路: ethereum
# 交易哈希: 0xf1f...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: Coinbase Deposit (0x9Dd)
# To: Coinbase: (unlabeled) (0xA9D)
# 價值: 1.683956935155764 ETH ($4987.055303033147 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x32a233435f662eea28ecd1171b0ca7068ef1da4bd9cde0d01de1e158211f2134
# 網路: ethereum
# 交易哈希: 0x32a...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0xe79)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 3.189139 ETH ($9444.66703989 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x066b70b0036e3d2a47870cc0e5093cfc0979c46de56520b4a569cba4b81d221e
# 網路: ethereum
# 交易哈希: 0x066...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0x859)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.09932317 ETH ($3255.6565611867004 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x53ca10b1ccf3f807d03d3fd0ebafe55b4f04f56bbfed48827da76b31f9c0fe55
# 網路: ethereum
# 交易哈希: 0x53c...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0x43D)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 3.70048683 ETH ($10959.0287519133 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x5226056425edb89637638295fe166939a51f1378977dd7f724dc794d8d85f84b
# 網路: ethereum
# 交易哈希: 0x522...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: OKX Deposit (0x278)
# To: OKX: (unlabeled) (0xBf9)
# 價值: 1.44519539 ETH ($4279.9605994389 USD)
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x475021e924a5861b02bfae080e7c84d69cefaa2db01ac9d753ada7bb504ef757
# 網路: ethereum
# 交易哈希: 0x475...
# 狀態: 成功
# 區塊: 19298603
# 時間: 2024-02-25 00:21:47 UTC+8
# From: None: (unlabeled) (0x846)
# To: Coinbase: (unlabeled) (0xA9D)
# 價值: 2.36152703 ETH ($6993.6859146153 USD)
# error: 0x34ea9a823ee139cad6509e5701d44350134d1637ef68713ba799eb02a9db92d0
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x34ea9a823ee139cad6509e5701d44350134d1637ef68713ba799eb02a9db92d0
# 網路: arbitrum_one
# 交易哈希: 0x34e...
# 狀態: 成功
# 區塊: 184046676
# 時間: 2024-02-25 00:21:41 UTC+8
# From: None: OKX Deposit (0x729)
# To: OKX: (unlabeled) (0x093)
# 價值: 3.70411184 ETH ($10969.764255278402 USD)
# error: 0xdfb27965f3bbb39353b5dfc1755b1baa25ccb4185feecfe8701784c4086a97c8
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xdfb27965f3bbb39353b5dfc1755b1baa25ccb4185feecfe8701784c4086a97c8
# 網路: polygon
# 交易哈希: 0xdfb...
# 狀態: 成功
# 區塊: 53907398
# 時間: 2024-02-25 00:21:30 UTC+8
# From: None: (unlabeled) (0x74A)
# To: OKX: OKX DEX (0x7a8)
# 價值: 12.745588421182779 LINK ($232.98935633922125 USD)
# error: 0x20dfaadde17688f9643785513ea893cc4533387af20910ee3bfc8de411c2f644
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x20dfaadde17688f9643785513ea893cc4533387af20910ee3bfc8de411c2f644
# 網路: arbitrum_one
# 交易哈希: 0x20d...
# 狀態: 成功
# 區塊: 184046448
# 時間: 2024-02-25 00:20:45 UTC+8
# From: None: OKX Deposit (0xbD1)
# To: OKX: (unlabeled) (0x093)
# 價值: 2.28111059 ETH ($6755.531823390901 USD)
# error: 0xff3d44bd7f3ddc6911398440030f4687f410fb8d895f6826643d6433c85f42ad
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xff3d44bd7f3ddc6911398440030f4687f410fb8d895f6826643d6433c85f42ad
# 網路: arbitrum_one
# 交易哈希: 0xff3...
# 狀態: 成功
# 區塊: 184046448
# 時間: 2024-02-25 00:20:45 UTC+8
# From: None: OKX Deposit (0xAc4)
# To: OKX: (unlabeled) (0x093)
# 價值: 30.00021076 ETH ($88845.92416784761 USD)
# error: 0x8f045cb7f98049beda4fb7d114626c978a3c3fd6ede3ab8477d69405389cf2d0
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x8f045cb7f98049beda4fb7d114626c978a3c3fd6ede3ab8477d69405389cf2d0
# 網路: base
# 交易哈希: 0x8f0...
# 狀態: 成功
# 區塊: 11001140
# 時間: 2024-02-25 00:20:27 UTC+8
# From: None: OKX Deposit (0xb36)
# To: OKX: (unlabeled) (0xFd9)
# 價值: 1.05997664 ETH ($3139.1314191264 USD)
# error: 0x49175f503be6d556b7e06109e18738d3a94094cf91009d80c0b1f231796e4daf
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x49175f503be6d556b7e06109e18738d3a94094cf91009d80c0b1f231796e4daf
# 網路: base
# 交易哈希: 0x491...
# 狀態: 成功
# 區塊: 11001140
# 時間: 2024-02-25 00:20:27 UTC+8
# From: None: OKX Deposit (0xd37)
# To: OKX: (unlabeled) (0xFd9)
# 價值: 1.07898037 ETH ($3195.4111555587006 USD)
# error: 0xe60db727066df48b5ec74a4c4f9399040ea3a8e856d5680843e5ca2576f6f413
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xe60db727066df48b5ec74a4c4f9399040ea3a8e856d5680843e5ca2576f6f413
# 網路: base
# 交易哈希: 0xe60...
# 狀態: 成功
# 區塊: 11001140
# 時間: 2024-02-25 00:20:27 UTC+8
# From: None: OKX Deposit (0x3E5)
# To: OKX: (unlabeled) (0xFd9)
# 價值: 1.018692 ETH ($3016.8665449200003 USD)
# error: 0x0e33ca862edbf08648da22e66e210b6b339967b7d5c972462d4e50563e98f4e4
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x0e33ca862edbf08648da22e66e210b6b339967b7d5c972462d4e50563e98f4e4
# 網路: arbitrum_one
# 交易哈希: 0x0e3...
# 狀態: 成功
# 區塊: 184046303
# 時間: 2024-02-25 00:20:09 UTC+8
# From: None: Binance Deposit (0x249)
# To: Binance: (unlabeled) (0xB38)
# 價值: 1.05648395 ETH ($3127.1396678024994 USD)
# error: 0x99a73d4b356af7ebe6b5556bbf16c6e37497e38113e6aa9f21ea4476de6ed699
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x99a73d4b356af7ebe6b5556bbf16c6e37497e38113e6aa9f21ea4476de6ed699
# 網路: arbitrum_one
# 交易哈希: 0x99a...
# 狀態: 成功
# 區塊: 184046298
# 時間: 2024-02-25 00:20:08 UTC+8
# From: None: Binance Deposit (0xA8f)
# To: Binance: (unlabeled) (0xB38)
# 價值: 1.6020949036 ETH ($4742.12080991082 USD)
# error: 0x44b3e51456548c50483277fdbfea9fd67ee0c82ecbaa78bed917605ab7545f29
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x44b3e51456548c50483277fdbfea9fd67ee0c82ecbaa78bed917605ab7545f29
# 網路: arbitrum_one
# 交易哈希: 0x44b...
# 狀態: 成功
# 區塊: 184046293
# 時間: 2024-02-25 00:20:06 UTC+8
# From: None: Binance Deposit (0xbAF)
# To: Binance: (unlabeled) (0xB38)
# 價值: 1.7362346023930433 ETH ($5139.1676113532885 USD)
# error: 0x6ec2662ecf7f6a81167ee80a39db2df7c41d8530514b2bdddcb20a9e5fbaa33a
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x6ec2662ecf7f6a81167ee80a39db2df7c41d8530514b2bdddcb20a9e5fbaa33a
# 網路: arbitrum_one
# 交易哈希: 0x6ec...
# 狀態: 成功
# 區塊: 184046289
# 時間: 2024-02-25 00:20:05 UTC+8
# From: None: Binance Deposit (0xC6F)
# To: Binance: (unlabeled) (0xB38)
# 價值: 1.741924596 ETH ($5156.0097079301995 USD)
# error: 0xade3dfd3b22fa099bbf1faabb322dc5d420e1a71d6d7714ba4feb966145dc494
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xade3dfd3b22fa099bbf1faabb322dc5d420e1a71d6d7714ba4feb966145dc494
# 網路: arbitrum_one
# 交易哈希: 0xade...
# 狀態: 成功
# 區塊: 184046284
# 時間: 2024-02-25 00:20:04 UTC+8
# From: None: Binance Deposit (0x91e)
# To: Binance: (unlabeled) (0xB38)
# 價值: 1.8916736170288972 ETH ($5599.259322724684 USD)
# error: 0xf00ce825854dcfebf21aa4389136fa250dc925ed2ef502f5092bad86f312f7e5
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0xf00ce825854dcfebf21aa4389136fa250dc925ed2ef502f5092bad86f312f7e5
# 網路: arbitrum_one
# 交易哈希: 0xf00...
# 狀態: 成功
# 區塊: 184046280
# 時間: 2024-02-25 00:20:03 UTC+8
# From: None: Binance Deposit (0xb91)
# To: Binance: (unlabeled) (0xB38)
# 價值: 4.197722238722726 ETH ($12425.047940507331 USD)
# error: 0x6462c83f58df226de439a767b7d3cb770024ac0566936459529fdd938727acad
# Check it on Arkham! => https://platform.arkhamintelligence.com/explorer/tx/0x6462c83f58df226de439a767b7d3cb770024ac0566936459529fdd938727acad
# 網路: arbitrum_one
# 交易哈希: 0x646...
# 狀態: 成功
# 區塊: 184046275
# 時間: 2024-02-25 00:20:02 UTC+8
# From: None: Binance Deposit (0x1c0)
# To: Binance: (unlabeled) (0xB38)
# 價值: 4.999956838599999 ETH ($14799.622244414068 USD)

# %%
while True:
    data = obj.request_tx()
    tx_list = data['transfers']
    for tx in tx_list:
        process(tx)
# Out:
# {'txid': '63d5b95a56d050c7754d9311d22fc19ff086f4e7bf1d955406518cb4c6b1e496', 'blockHash': '00000000000000000003b48409bfda612c422d06f576527ae9bcc8b9381d36bb', 'blockHeight': 827244, 'blockTimestamp': '2024-01-25T02:40:01Z', 'unitValue': 56.57822962, 'historicalUSD': 2262054.19843722, 'toAddress': {'address': '3FM9vDYsN2iuMPKWjAcqgyahdwdrUxhbJ3', 'chain': 'bitcoin', 'arkhamEntity': {'name': 'VanEck', 'note': '', 'id': 'vaneck', 'type': 'fund', 'service': None, 'addresses': None, 'website': 'https://www.vaneck.com', 'twitter': 'https://twitter.com/vaneck_us'}, 'arkhamLabel': {'name': 'HODL Bitcoin ETF', 'address': '3FM9vDYsN2iuMPKWjAcqgyahdwdrUxhbJ3', 'chainType': 'bitcoin'}, 'isUserAddress': False}, 'fromCoinbase': False, 'fromAddresses': [{'address': {'address': 'bc1qfcmkafyvsa8r72uv0ahcv2qz9ad7m2g34rnfd5', 'chain': 'bitcoin', 'arkhamEntity': {'name': 'Gemini', 'note': '', 'id': 'gemini', 'type': 'cex', 'service': None, 'addresses': None, 'website': 'https://gemini.com', 'twitter': 'https://twitter.com/Gemini', 'crunchbase': 'https://www.crunchbase.com/organization/gemini-99b2', 'linkedin': 'https://www.linkedin.com/company/geminitrust'}, 'isUserAddress': False}, 'value': 56.946803}], 'fromValue': 56.946803}
