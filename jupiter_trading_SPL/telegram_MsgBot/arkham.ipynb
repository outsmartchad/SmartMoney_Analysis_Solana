# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# Golbal variable

# %%
api_key = "zDsBxfwJhW90YOS74kG4H509veFL7BDa"
root_url = "https://api.arkhamintelligence.com"
headers = {
    "API-Key": api_key
}
funds = {
    'Grayscale': "grayscale",
    'BlackRock': "blackrock",
    'Fidelity': "fidelity",
    'Bitwise': "bitwise",
    'VanEck': "vaneck",
    
}
cexes ={
    'Binance': "binance",
    'Coinbase': "coinbase",
    'OKX': "okx",
    'Bitfinex': "bitfinex"
}
tokens = {
    'BTC': "bitcoin",
    'ETH': "ethereum",
    
}
fromArr = [funds['Grayscale'], funds['Fidelity'], funds['BlackRock'], funds['Bitwise'], funds['VanEck']]
baseArr = fromArr
etherscanRoot = f'https://etherscan.io/tx/'
bitcoinRoot = f'https://blockstream.info/tx/'
arkhamEntityRoot = f'https://platform.arkhamintelligence.com/explorer/entity/'
arkhamAddressRoot = f'https://platform.arkhamintelligence.com/explorer/address/'

# %%
class arkham_transfer: # path = "/transfer"
        
        def __init__(self, base=[], chains=[], flow="all", From=[], to=[], tokens=[], timeGte=0, 
                    timeLte=0, timeLast="1m", valueGte=0, valueLte=0, usdGte=0, usdLte=0, sortKey="value", sortDir="desc", limit=20, offset=100):
            self.params = {
                "base" : base, # ftx, binance, grayscale...
                "chains" : chains, # ethereum, bitcoin...
                "flow" : flow, # in, out, default = all
                "from" : From, # type:binance,despoit:all
                "to" : to, # just like from
                "tokens" : tokens, # tokens address
                "timeGte" : timeGte, #篩選出區塊_時間戳大於或等於特定時間的交易。
                "timeLte" : timeLte, #篩選出區塊_時間戳<於或等於特定時間的交易。
                "timeLast" : timeLast, # last 1d, 1h, 1m, 1s
                "valueGte" : valueGte, # 篩選出超過特定代幣單位價值的轉帳資訊  
                "valueLte" : valueLte, # 篩選出<過特定代幣單位價值的轉帳資訊
                "usdGte" : usdGte, # just like valueGte, but in usd base format
                "usdLte" : usdLte,
                "sortKey" : sortKey, # "time", "value", "usd"
                "sortDir" : sortDir, # "asc", "desc"
                "limit" : limit, # 返回的轉帳結果數量，預設至20筆。最多10,000筆。
                "offset" : offset,   
            }
            self.url = "/transfers"
        
        def set_params(self, params):
            self.params = params
        def get_params(self):
            return self.params
        def request_tx(self):
            data = requests.get(url=f'{root_url}{self.url}', headers=headers, params=self.params)
            if data.status_code == 200:
                return data.json()
            else:
                print("Error! "+str(data.status_code))
                return None

# %%
def convertTimeStampToUTCTime(time):
    utc_time = datetime.utcfromtimestamp(float(time))
    utc_time_plus_8 = utc_time + timedelta(hours=16)
    date_str = utc_time_plus_8.strftime('%Y-%m-%d %H:%M:%S')
    return date_str
def convertBlockTimeToUTCTime(blockTimestamp):
    datetimeobj = datetime.strptime(blockTimestamp, '%Y-%m-%dT%H:%M:%SZ')
    timestamp = datetimeobj.timestamp()
    return convertTimeStampToUTCTime(timestamp)
def get_cur_timestamp():
        # Get the current time in UTC+8
    current_time = datetime.now()
    # Calculate the start time for the last 60 minutes
    start_time = current_time

    # Convert the start time to a timestamp in milliseconds
    active_timeStamp = int(start_time.timestamp())*1000

    utc_time = datetime.utcfromtimestamp(active_timeStamp/1000) + timedelta(hours=8)
    date_str = utc_time.strftime('%Y-%m-%d %H:%M:%S')
    print(date_str)
    return int(active_timeStamp/1000)
def get_last_3_min_timestamp(timeStamp):
    timeStamp = float(timeStamp)
    utc_time = datetime.utcfromtimestamp(timeStamp) - timedelta(minutes=3)
    res = utc_time
    utc_time = utc_time + timedelta(hours=8)
    date_str = utc_time.strftime('%Y-%m-%d %H:%M:%S')
    print(date_str)
    return int(res.timestamp())

# %%
obj = arkham_transfer()

params = {
    "base": baseArr, 
    "flow" : "all",
    "to": ['coinbase-prime'],
    "timeLast": "12h",
    "tokens": [tokens['BTC'], tokens['ETH']],
    "sortKey": "time",
    "valueGte" : 0.03, # 篩選出超過特定代幣單位價值的轉帳資訊  
    "sortDir": "desc",
    "limit": 10000,
}
obj.set_params(params)

# %%
# toAddress would probably be a list of address labeled as a entity name
# just loop through the toAddress list and find the first labeled address and get the entity name then done, 
# seem as the list of fromAddress 
# EntityA: len(toAddress), EntityB: len(FromAddress)
# Transfer value = 'fromValue'
# we want:
# 1. ['fromAddress']['arkhamEntity']['name']
# or ['fromAddresses'][n]['arkhamEntity']['name']
# Out:
# 1171.06996889

# %% [markdown]
# # examples

# %%
data = {'id': '0x5535683927cb482040f99efba1831fababea2a7d5087c2febe866601d6799d85_183',
 'transactionHash': '0x5535683927cb482040f99efba1831fababea2a7d5087c2febe866601d6799d85',
 'fromAddress': {'address': '0xCD531Ae9EFCCE479654c4926dec5F6209531Ca7b',
  'chain': 'ethereum',
  'arkhamEntity': {'name': 'Coinbase Prime',
   'note': '',
   'id': 'coinbase-prime',
   'type': 'cex',
   'service': None,
   'addresses': None,
   'website': 'https://www.coinbase.com/prime',
   'twitter': 'https://twitter.com/CoinbaseInsto'},
  'isUserAddress': False,
  'contract': False},
 'fromIsContract': False,
 'toAddress': {'address': '0x404De972e8138C4982ace8Bdd7fc0E755DE33AFd',
  'chain': 'ethereum',
  'arkhamEntity': {'name': 'Bitwise',
   'note': '',
   'id': 'bitwise',
   'type': 'fund',
   'service': None,
   'addresses': None,
   'website': 'https://bitwiseinvestments.com/',
   'twitter': 'https://twitter.com/BitwiseInvest'},
  'arkhamLabel': {'name': 'DeFi Crypto Index Fund',
   'address': '0x404De972e8138C4982ace8Bdd7fc0E755DE33AFd',
   'chainType': 'evm'},
  'isUserAddress': False,
  'contract': False},
 'toIsContract': False,
 'tokenAddress': '0x1f9840a85d5aF5bf1D1762F925BDADdC4201F984',
 'type': 'token',
 'blockTimestamp': '2024-01-25T07:54:35Z',
 'blockNumber': 19082268,
 'blockHash': '0x4cc147529150969309227174d1cbb054815127c1d565562603b14d79d8447b05',
 'tokenName': 'Uniswap',
 'tokenSymbol': 'UNI',
 'tokenDecimals': 18,
 'unitValue': 5270.000000000001,
 'tokenId': 'uniswap',
 'historicalUSD': 30671.400000000005,
 'chain': 'ethereum'}

# %%
print(data['fromAddress']['arkhamEntity']['name'])
print(convertBlockTimeToUTCTime(data['blockTimestamp']))
# Out:
# Coinbase Prime
# 2024-01-25 15:54:35

# %% [markdown]
# ## Examples of message

# %% [markdown]
# Network: Ethereum (1)
# Transaction Hash: 0x..... (should be a hyperlink) (1)
# State: Successful (1)
# Block: #3123213 (1)
# Time: 3 小时 前( 1月25, 2024 15:54:35 UTC+8) (1)
# From: EntityA (1)
# To: EntityB (1)
# Value: 1 ETH ($2330 USD) (1)
#
# 網路：以太坊 (1)
# 交易哈希：0x.....（應該是超連結）(1)
# 狀態：成功 (1)
# 區塊：#3123213 (1)
# 時間: 3小時前( 2024年1月25日 15:54:35 UTC+8) (1)
# 來自：實體A (1)
# 至：實體B (1)
# 價值：1 ETH（2330 美元）(1)

# %%
def findTheMostValueAddress(addressList):
    bestValue = None
    resEntity, resAddress, resLabel, resChain  = None, None, None, None
    for address in addressList:
        each = address['address']
        curValue = address['value']
        if bestValue == None: 
            bestValue = curValue
            if 'arkhamLabel' in each: resLabel = each['arkhamLabel']['name']
            if 'chain' in each:
                resChain = each['chain']
            if 'arkhamEntity' in each:
                resEntity = each['arkhamEntity']['name']
            if 'address' in each:
                resAddress = each['address']
        if curValue > bestValue:
            if 'arkhamLabel' in each: resLabel = each['arkhamLabel']['name']
            if 'chain' in each:
                resChain = each['chain']
            if 'arkhamEntity' in each:
                resEntity = each['arkhamEntity']['name']
            if 'address' in each:
                resAddress = each['address']
            bestValue = curValue
    
    return resChain, resEntity, resLabel, resAddress

# %%
def process(tx):
    
    try:
        # divide all the userful data
        chain,txhash,block,time,From,to,value = None,None,None,None,None,None,None
        fromArkhamLabeledName, USDValue, toArkhamLabeledName = None, None, None
        fromAddress, toAddress, toEntity, fromEntity = None, None, None, None
        # fromAddresses or fromAddress
        # toAddresses or toAddress
        # to find the token name, the network, the from's entity, and the to's entity
        
        # from entity
        if 'fromAddress' in tx:
            From = tx['fromAddress']
            if 'arkhamLabel' in From: fromArkhamLabeledName = From['arkhamLabel']['name']
            chain = From['chain']
            if 'arkhamEntity' in From: fromEntity = From['arkhamEntity']['name']
            if 'address' in From: fromAddress = From['address']
        else: # fromAddresses
            addressList = tx['fromAddresses']
            for address in addressList:
                each = address['address']
                if 'arkhamLabel' in each: fromArkhamLabeledName = each['arkhamLabel']['name']
                if 'chain' in each:
                    chain = each['chain']
                if 'arkhamEntity' in each:
                    fromEntity = each['arkhamEntity']['name']
                if 'address' in each: 
                    fromAddress = each['address']
                if chain != None and fromEntity != None: break
                
        # to entity
        if 'toAddress' in tx:
            to = tx['toAddress']
            if 'arkhamLabel' in to: toArkhamLabeledName = to['arkhamLabel']['name']
            chain = to['chain']
            if 'arkhamEntity' in to: toEntity = to['arkhamEntity']['name']
            if 'address' in to: toAddress = to['address']
        else: # toAddresses
            addressList = tx['toAddresses']
            chain, toEntity, toArkhamLabeledName, toAddress = findTheMostValueAddress(addressList=addressList)

        if 'transactionHash' in tx:
            txhash = tx['transactionHash'] 
        elif 'txid' in tx:
            txhash = tx['txid']
        if 'blockTimestamp' in tx:
            time =str(convertBlockTimeToUTCTime(tx['blockTimestamp'])) + " UTC+8"
        if 'blockNumber' in tx:
            block = "#"+str(tx['blockNumber'])
        elif 'blockHeight' in tx:
            block = "#"+str(tx['blockHeight'])
        if 'fromValue' in tx:
            value = str(tx['fromValue'])
        else:
            value = tx["unitValue"]
        USDValue = f"(${tx['historicalUSD']} USD)"
        # convert them to readable text
        if chain == 'ethereum':
            txhash = etherscanRoot+txhash
            valueFormat = 'ETH'
        elif chain == 'bitcoin':
            txhash = bitcoinRoot+txhash
            valueFormat = 'BTC'
        else:
            print("error: "+txhash)
        if fromArkhamLabeledName == None: fromArkhamLabeledName = '(unlabeled)'
        if toArkhamLabeledName == None: toArkhamLabeledName = '(unlabeled)'
        # toLink = f'<a href="{arkhamEntityRoot}{to.lower()}">{toArkhamLabeledName}</a>'
        # fromLink = f'<a href="{arkhamEntityRoot}{From.lower()}">{fromArkhamLabeledName}</a>'
        msg = f"網路: {chain}\n交易哈希: {txhash}\n狀態: 成功\n區塊: {block}\n時間: {time}\nFrom: {fromEntity}: {fromArkhamLabeledName} ({fromAddress})\nTo: {toEntity}: {toArkhamLabeledName} ({toAddress})\n價值: {value} {valueFormat} {USDValue}"
        # send it to the telegram chat
        print(msg)
    except Exception as e:
        print("發生異常：", str(e))
        print("txHash: "+txhash)

# %%
obj.get_params()
obj.request_tx()
# Out:
# Error! 401

# %%
data = obj.request_tx()
tx_list = data['transfers']
for tx in tx_list:
    process(tx)
# Out:
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/c59b2c439e63c11a5d8fba720a2f6b75ba6617e038081606866c48912e87adb0
# 狀態: 成功
# 區塊: #827344
# 時間: 2024-01-26 02:03:27 UTC+8
# From: Coinbase Prime: Hot Wallet (3MqUP6G1daVS5YTD8fz3QgwjZortWwxXFd)
# To: BlackRock: IBIT Bitcoin ETF (1BoTSXbPJqept6saHPCW6U1Uj4RmVbEeWW)
# 價值: 519.89264948 BTC ($18452450.59664578 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/237fab234d5977437df472171079316f6e9deaf5a15adb16ae338f942a7804b4
# 狀態: 成功
# 區塊: #827343
# 時間: 2024-01-26 01:54:46 UTC+8
# From: Coinbase Prime: Hot Wallet (3MqUP6G1daVS5YTD8fz3QgwjZortWwxXFd)
# To: BlackRock: IBIT Bitcoin ETF (1Dmjds2Yx4TuNqpdGVgHLi4TeYv2EcNaso)
# 價值: 1363.31738613 BTC ($47776800 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/5eff8f8875dc6d8046bf718721164af335b370af9b81014b352c5d43cf68ea39
# 狀態: 成功
# 區塊: #827333
# 時間: 2024-01-26 00:54:48 UTC+8
# From: Gemini: (unlabeled) (19bBHjBXcWGwGqUvS5Pkwn9YgkZDWBGdAb)
# To: VanEck: HODL Bitcoin ETF (3FM9vDYsN2iuMPKWjAcqgyahdwdrUxhbJ3)
# 價值: 57 BTC ($2250738.55251322 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/1d27f3039edc7feab2fb18628241f4998f9829fb15c34aee6b8ca6a74fb25ab4
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Bitwise: BITB Bitcoin ETF (1K5EW6HLqLTwUmnpnNfkvSej4oT2CbWbPk)
# To: Bitwise: BITB Bitcoin ETF (1CKVszDdUp4ymGceAZpGzYEFr4RPNHYqaM)
# 價值: 479.79786232 BTC ($19146813.49374192 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (1GVqTWhWJTkL8yWyjmPZY6XEUWxaADz3tj)
# To: Grayscale: Coinbase Prime Deposit (36hGZcTFL9KBwjHE3hYiEAfh8xn876GoxF)
# 價值: 900.00004379 BTC ($35915401.74748374 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/a2753996bb1084d370b198efbd2173c7d6214a1a3632be657109dcc50a99aa0f
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (1G8EWgNWvpXGDvP7NaDn3cbdk6jbiBXn11)
# To: Grayscale: Coinbase Prime Deposit (3QwWzj6D8zzWeZ99xtYLnqmgDV5Vkew5cV)
# 價值: 900.00004379 BTC ($35915401.74748374 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/02d77109fd3523d7139593e56e7af8a6cda6b131ffe125438a3a29b97c7f6e72
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (12BGWrHn9xwnL4hUmKfKRjsrdLrGbQ9Nmk)
# To: Grayscale: Coinbase Prime Deposit (3QwWzj6D8zzWeZ99xtYLnqmgDV5Vkew5cV)
# 價值: 765.92494776 BTC ($30565000.96531056 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/6755f8069c7c42eaa8ce97cfdee2be25895c0231c72de2848e1b21a0547c4c62
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (1DYrDSDNv1bYKvaqH84wBqyK4kLDi8Qibr)
# To: Grayscale: Coinbase Prime Deposit (3JTBPQvoxWq8QTXdEUJKqbsbsbGVzU7pNR)
# 價值: 731.91588676 BTC ($29207835.37704456 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/8dfb6fa0d744c9ab32d74f4eb60444abc9bdf66ff519b7a40f51d86c14bee4f0
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (1CEL7p7owPFK4nx9xBVNNrNu6yPvzR4p7m)
# To: Grayscale: Bitcoin Trust (1K5NibPEvduqEWDJvC8EJ1ZK3Gr1fwtvzC)
# 價值: 900.00004379 BTC ($39851.5043664 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/a013b943588ccf4020129d1d89ee3230ecdfe6cc8120ff0a056999cf45bd605e
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (16akPLxPFvyo8RbdHKRbi3TL6PT4AWvaCM)
# To: Grayscale: Coinbase Prime Deposit (3Chmt4tE7eaTqdh1PNMCZcDaWr2BLwJ9bS)
# 價值: 767.46875183 BTC ($30626608.01052798 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/c262a0f72a0ca3abc3f16809708155e13116ec12889775e62348caf52caeaba3
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (15o3NMjskxjakMf6DqAVw2UKTbsmXzzgC5)
# To: Grayscale: Bitcoin Trust (1L9xHPWm6AVWu8mRasPC3GctcssgEppR3m)
# 價值: 950.00004376 BTC ($37910701.74628656 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/d26b474ff89ff0cebe662364dfe905e61985af8dbc5864910f4e768c644f35fe
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (161LKpKyFVVLapwK5iEBecune14QA1WWbg)
# To: Grayscale: Coinbase Prime Deposit (3Chmt4tE7eaTqdh1PNMCZcDaWr2BLwJ9bS)
# 價值: 1000.00003282 BTC ($39906001.30971492 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/8dfb6fa0d744c9ab32d74f4eb60444abc9bdf66ff519b7a40f51d86c14bee4f0
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (1CEL7p7owPFK4nx9xBVNNrNu6yPvzR4p7m)
# To: Grayscale: Coinbase Prime Deposit (3QwWzj6D8zzWeZ99xtYLnqmgDV5Vkew5cV)
# 價值: 900.00004379 BTC ($35915401.74748374 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/79b66b1758b6ed71eb9033428202a5366b144021efef2ac0e3e34c51be5126f5
# 狀態: 成功
# 區塊: #827318
# 時間: 2024-01-25 22:14:57 UTC+8
# From: Grayscale: Bitcoin Trust (197tTZBw1TkTeSW7gSxUcyHA8SR7NBLLoi)
# To: Grayscale: Coinbase Prime Deposit (3QwWzj6D8zzWeZ99xtYLnqmgDV5Vkew5cV)
# 價值: 900.00004926 BTC ($35915401.96576956 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/efa185d9102c292da171924e33b6b10d8b62dc2e1d18a965e691f66fcab62d4b
# 狀態: 成功
# 區塊: #827313
# 時間: 2024-01-25 21:35:04 UTC+8
# From: None: (unlabeled) (bc1qlaw9lygwc342d8nvrrllculgrxwyalpr5k47y3)
# To: Bitwise: BITB Bitcoin ETF (1K5EW6HLqLTwUmnpnNfkvSej4oT2CbWbPk)
# 價值: 549.32320787 BTC ($19136250.76165088 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/e45accfea6711d9e832f1de89513df4e1a145ef998d0d9c19c4ba183d89f2dcf
# 狀態: 成功
# 區塊: #827313
# 時間: 2024-01-25 21:35:04 UTC+8
# From: None: (unlabeled) (bc1q8s3h3vw5xufdas890q29lpuca56r0ezqar0mvs)
# To: Fidelity: FBTC Bitcoin ETF (32TiohXoCmHr87xVm3E9A3sLiWBJjYn1gf)
# 價值: 2068.73511359 BTC ($79768000 USD)
# 網路: bitcoin
# 交易哈希: https://blockstream.info/tx/c7ef079856defd74488f6d7ba81848fad6b51b865df557076935de99322e0e2e
# 狀態: 成功
# 區塊: #827281
# 時間: 2024-01-25 16:25:39 UTC+8
# From: Coinbase: (unlabeled) (36ypEMheTbiazkuBXaQehNWXHgqdttZnRt)
# To: Fidelity: FBTC Bitcoin ETF (3NpXph8WN1U9hwXjg1bRtzTff1tPR2Gpw4)
# 價值: 1171.06996889 BTC ($46886093.6098398 USD)

# %%
while True:
    data = obj.request_tx()
    tx_list = data['transfers']
    for tx in tx_list:
        process(tx)
# Out:
# {'txid': '63d5b95a56d050c7754d9311d22fc19ff086f4e7bf1d955406518cb4c6b1e496', 'blockHash': '00000000000000000003b48409bfda612c422d06f576527ae9bcc8b9381d36bb', 'blockHeight': 827244, 'blockTimestamp': '2024-01-25T02:40:01Z', 'unitValue': 56.57822962, 'historicalUSD': 2262054.19843722, 'toAddress': {'address': '3FM9vDYsN2iuMPKWjAcqgyahdwdrUxhbJ3', 'chain': 'bitcoin', 'arkhamEntity': {'name': 'VanEck', 'note': '', 'id': 'vaneck', 'type': 'fund', 'service': None, 'addresses': None, 'website': 'https://www.vaneck.com', 'twitter': 'https://twitter.com/vaneck_us'}, 'arkhamLabel': {'name': 'HODL Bitcoin ETF', 'address': '3FM9vDYsN2iuMPKWjAcqgyahdwdrUxhbJ3', 'chainType': 'bitcoin'}, 'isUserAddress': False}, 'fromCoinbase': False, 'fromAddresses': [{'address': {'address': 'bc1qfcmkafyvsa8r72uv0ahcv2qz9ad7m2g34rnfd5', 'chain': 'bitcoin', 'arkhamEntity': {'name': 'Gemini', 'note': '', 'id': 'gemini', 'type': 'cex', 'service': None, 'addresses': None, 'website': 'https://gemini.com', 'twitter': 'https://twitter.com/Gemini', 'crunchbase': 'https://www.crunchbase.com/organization/gemini-99b2', 'linkedin': 'https://www.linkedin.com/company/geminitrust'}, 'isUserAddress': False}, 'value': 56.946803}], 'fromValue': 56.946803}
